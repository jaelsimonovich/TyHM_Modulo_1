# %%
#Este es mi primer cuaderno

#Aquí voy a mezclar código markdown cin operaciones matemáticas
*sumar
*restar
*multiplicar
*dividir

# %%
a=5
b=7
a+b
# Out:
# [1] 12

# %% [markdown]
# Entramos a Google Collab, pusimos en archivo nuevo libro en drive
# Ahí se abrió otra ventana en el libro de drive, luego en editar, configuración de cuaderno y seleccionamos lenguaje R y CPU, lo demás no se toca. Listo.
# Para escribir texto seleccionamos en +texto
# O para escribir código hay que seleccionar +código
